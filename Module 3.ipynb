# %% [markdown]
# ## PROBLEM STATEMENT
# # 3.1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
gold_data = pd.read_csv('Gold.csv')
gold_data.set_index('Date', inplace = True)
gold_data_nan = gold_data.dropna()
gold_data_nan
# Out:
#               Price   Open   High    Low    Vol. Change %   Pred         new
# Date
# May 04, 2017  28060  28400  28482  28025   0.08K   -1.79%  738.0  117.570740
# May 05, 2017  28184  28136  28382  28135   0.06K    0.44% -146.0  295.430176
# May 08, 2017  28119  28145  28255  28097   7.85K   -0.23%   30.0  132.123714
# May 09, 2017  27981  28125  28192  27947  10.10K   -0.49%  357.0  101.298064
# May 10, 2017  28007  28060  28146  27981   9.28K    0.09%  124.0  112.153318
# ...             ...    ...    ...    ...     ...      ...    ...         ...
# Dec 04, 2018  30964  30874  31085  30874   0.08K    0.57%  -31.0  301.615081
# Dec 05, 2018  30926  30830  30970  30825   0.04K   -0.12%   72.0  241.475101
# Dec 06, 2018  31005  31039  31196  30974  10.55K    0.26%   35.0  188.222186
# Dec 07, 2018  31440  31011  31480  30941  11.24K    1.40%  669.0  976.692705
# Dec 10, 2018  31895  31459  31966  31420  14.09K    1.45%  521.0  990.254297
#
# [411 rows x 8 columns]

# %%
#regression
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

y = np.array(gold_data_nan["Pred"])
x = np.array(gold_data_nan["new"])
y = y.reshape(-1,1)
x = x.reshape(-1,1)

regression_model = LinearRegression()
# fitting the data
regression_model.fit(x, y)
# predicting the data
y_predicted = regression_model.predict(x)

# root mean square error
rmse = mean_squared_error(y, y_predicted)
r2 = r2_score(y, y_predicted)

print('Slope:', regression_model.coef_)
print('Intercept:', regression_model.intercept_)
print('Root Mean Squared', rmse)
print('R2 Score:', r2)


# plotting the graph
plt.scatter(x, y, s=10)
plt.xlabel('x')
plt.ylabel('y')

# predicted values
plt.plot(x, y_predicted, color = 'r')
plt.show()
# Out:
# Slope: [[-0.00823083]]
# Intercept: [343.67028421]
# Root Mean Squared 73300.46132887459
# R2 Score: 3.732507600850976e-05

# %%
gold_data = pd.read_csv('Gold.csv')
pre_data = gold_data[:]
pre_new = pre_data['new']
pre_new = pre_new.values.reshape(-1,1)
na_data = (regression_model.predict(pre_new))
na_data_series = pd.Series(na_data.ravel())
sata = na_data_series.to_frame()
gold_data['Pred'] = sata
gold_data
# Out:
#              Date  Price   Open   High    Low    Vol. Change %        Pred  \
# 0    May 04, 2017  28060  28400  28482  28025   0.08K   -1.79%  342.702580
# 1    May 05, 2017  28184  28136  28382  28135   0.06K    0.44%  341.238649
# 2    May 08, 2017  28119  28145  28255  28097   7.85K   -0.23%  342.582797
# 3    May 09, 2017  27981  28125  28192  27947  10.10K   -0.49%  342.836517
# 4    May 10, 2017  28007  28060  28146  27981   9.28K    0.09%  342.747169
# ..            ...    ...    ...    ...    ...     ...      ...         ...
# 507  Apr 26, 2019  31868  31851  31934  31705   9.67K    0.08%  341.635810
# 508  Apr 30, 2019  31625  31800  31824  31597   6.44K   -0.76%  343.240625
# 509  May 01, 2019  31563  31604  31657  31503   1.55K   -0.20%  342.737786
# 510  May 02, 2019  31203  31420  31425  31160   0.48K   -1.14%  343.272194
# 511  May 03, 2019  31341  31250  31500  31163   0.08K    0.44%  340.131646
#
#             new
# 0    117.570740
# 1    295.430176
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

y = np.array(gold_data["new"])
x = np.array(gold_data["Pred"])
y = y.reshape(-1,1)
x = x.reshape(-1,1)

regression_model = LinearRegression()
regression_model.fit(x, y)
y_predicted = regression_model.predict(x)

rmse = mean_squared_error(y, y_predicted)
r2 = r2_score(y, y_predicted)

print("Slope:", regression_model.coef_)
print('Intercept:', regression_model.intercept_)
print('Root Mean Squared Error:', rmse)
print('R2 Score:', r2)

# plotting the graph
plt.scatter(x, y, s=10)
plt.xlabel('x')
plt.ylabel('y')

# predicted values
plt.plot(x, y_predicted, color = 'r')
plt.show()
# Out:
# Slope: [[-121.49444741]]
# Intercept: [41754.03127127]
# Root Mean Squared Error: 2.0681422785657492e-23
# R2 Score: 1.0

# %%
import matplotlib.pyplot as plt

plt.hist(gold_data['Pred'])
plt.show()

# %%
import seaborn as sns

sns.distplot(gold_data['Pred'])
plt.show()

# %% [markdown]
# ## PROBLEM STATEMENT
# # 3.2

# %%
import pandas as pd

INFY = pd.read_csv('INFY.csv')
INFY['Date'] = pd.to_datetime(INFY['Date'])
INFY.set_index('Date', inplace=True)
INFY = INFY.sort_values('Date')
INFY
# Out:
#            Symbol Series  Prev Close  Open Price  High Price  Low Price  \
# Date
# 2017-05-15   INFY     EQ      964.25      963.50      963.50     949.10
# 2017-05-16   INFY     EQ      951.55      953.10      960.15     946.95
# 2017-05-17   INFY     EQ      955.00      951.60      958.45     943.85
# 2017-05-18   INFY     EQ      952.80      943.00      973.90     942.85
# 2017-05-19   INFY     EQ      961.75      961.50      962.70     947.85
# ...           ...    ...         ...         ...         ...        ...
# 2019-05-07   INFY     EQ      718.40      720.40      727.90     718.70
# 2019-05-08   INFY     EQ      724.55      721.00      726.00     716.50
# 2019-05-09   INFY     EQ      719.35      719.15      730.30     715.80
# 2019-05-10   INFY     EQ      721.05      720.80      726.00     715.00
# 2019-05-13   INFY     EQ      716.85      716.55      726.45     712.10
#
#             Last Price  Close Price  Average Price  Total Traded Quantity  \
# Date
# ...

# %%
import pandas as pd

Nifty = pd.read_csv('Nifty50.csv')
Nifty['Date'] = pd.to_datetime(Nifty['Date'])
Nifty = Nifty.sort_values('Date')
Nifty.set_index('Date', inplace=True)
Nifty
# Out:
#                 Open      High       Low     Close  Shares Traded  \
# Date
# 2017-05-15   9433.55   9449.25   9423.10   9445.40      145163953
# 2017-05-16   9461.00   9517.20   9456.35   9512.25      171709433
# 2017-05-17   9517.60   9532.60   9486.10   9525.75      211856040
# 2017-05-18   9453.20   9489.10   9418.10   9429.45      199340647
# 2017-05-19   9469.90   9505.75   9390.75   9427.90      259861396
# ...              ...       ...       ...       ...            ...
# 2019-05-07  11651.50  11657.05  11484.45  11497.90      337495624
# 2019-05-08  11478.70  11479.10  11346.95  11359.45      372826025
# 2019-05-09  11322.40  11357.60  11255.05  11301.80      373028059
# 2019-05-10  11314.15  11345.80  11251.05  11278.90      387323416
# 2019-05-13  11258.70  11300.20  11125.60  11148.20      357586433
#
#             Turnover (Rs. Cr)
# Date
# 2017-05-15            7790.97
# 2017-05-16            9209.89
# 2017-05-17           10726.23
# 2017-05-18           10782.46
# ...

# %%
INFY_filt = INFY[406:]
Nifty_filt = Nifty[404:]

# %%
pct_INFY = INFY_filt['Close Price'].pct_change()
pct_Nif = Nifty_filt['Close'].pct_change()

# %%
plt.figure(figsize=(20,10))

pct_INFY.plot()
pct_Nif.plot()
plt.ylabel("Daily Return of INFY and NIFTY")
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

INFY_filt['pct_change'] = INFY_filt['Close Price'].pct_change()
Nifty_filt['pct_change'] = Nifty_filt['Close'].pct_change()

# %%
import pandas as pd 
import statsmodels.api as sm

x = INFY_filt['pct_change'].dropna()
x = list(x)
y = Nifty_filt['pct_change'].dropna()
y = list(y)

myModel = sm.OLS(y, x).fit()
myModel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.011
# Method:                 Least Squares   F-statistic:                            0.02814
# Date:                Thu, 14 May 2020   Prob (F-statistic):                       0.867
# Time:                        00:10:28   Log-Likelihood:                          316.97
# No. Observations:                  89   AIC:                                     -631.9
# Df Residuals:                      88   BIC:                                     -629.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
import pandas as pd
import statsmodels.api as sm

Infy = pd.read_csv('INFY.csv', parse_dates=True, index_col='Date')
Nifty = pd.read_csv('Nifty50.csv', parse_dates=True, index_col='Date')


monthly_price = pd.concat([Infy['Close Price'], Nifty['Close']], axis=1)
monthly_price.columns = ['INFY', 'Nifty50']

print(monthly_price.head())

monthly_return = monthly_price.pct_change(1)
clean_monthly_return = monthly_return.dropna(axis=0)
print(clean_monthly_return.head())
# Out:
#               INFY  Nifty50
# Date
# 2017-05-15  951.55  9445.40
# 2017-05-16  955.00  9512.25
# 2017-05-17  952.80  9525.75
# 2017-05-18  961.75  9429.45
# 2017-05-19  957.95  9427.90
#                 INFY   Nifty50
# Date
# 2017-05-16  0.003626  0.007078
# 2017-05-17 -0.002304  0.001419
# 2017-05-18  0.009393 -0.010109
# 2017-05-19 -0.003951 -0.000164
# 2017-05-22  0.003654  0.001098

# %%
X = clean_monthly_return['INFY']
y = clean_monthly_return['Nifty50']

X1 = sm.add_constant(X)

model = sm.OLS(y, X1)

result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                Nifty50   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.039
# Method:                 Least Squares   F-statistic:                     20.84
# Date:                Thu, 14 May 2020   Prob (F-statistic):           6.31e-06
# Time:                        00:44:43   Log-Likelihood:                 1751.1
# No. Observations:                 495   AIC:                            -3498.
# Df Residuals:                     493   BIC:                            -3490.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0004      0.000      1.154      0.249      -0.000       0.001
# ...

# %%
# Daily beta value for last 3 months for stock INFY is 0.0098 which is less than 1 hence it is less volatile.
# Monthly beta value for INFY is 0.0550 which is less than 1 hence it is less volatile.
